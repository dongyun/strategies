# %% [markdown]
# # 动量策略

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import matplotlib as mpl
mpl.rcParams['font.family'] = 'serif'
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### 前导知识与复习

# %%
import numpy as np
import pandas as pd
import tushare as ts

# %%
np.sign(-0.2)
# Out:
# -1.0

# %%
date = '2018-12-22'
type(date)
# Out:
# str

# %%
data = pd.to_datetime('2012-12-03')
type(data)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ### 1.数据准备与回测准备

# %%
data = ts.get_k_data('hs300',start='2015-01-01',end='2019-12-20')[['date','close']]

# %%
data.rename(columns={'close':'price'}, inplace=True)

# %%
data.set_index('date',inplace=True)

# %%
data.head()
# Out:
#               price
# date
# 2015-01-05  3641.54
# 2015-01-06  3641.06
# 2015-01-07  3643.79
# 2015-01-08  3559.26
# 2015-01-09  3546.72

# %%
data['returns'] = np.log(data['price'] / data['price'].shift(1))

# %%
data.head()
# Out:
#               price   returns
# date
# 2015-01-05  3641.54       NaN
# 2015-01-06  3641.06 -0.000132
# 2015-01-07  3643.79  0.000750
# 2015-01-08  3559.26 -0.023472
# 2015-01-09  3546.72 -0.003529

# %%
data['position'] = np.sign(data['returns'])

# %%
data.head()
# Out:
#               price   returns  position
# date
# 2015-01-05  3641.54       NaN       NaN
# 2015-01-06  3641.06 -0.000132      -1.0
# 2015-01-07  3643.79  0.000750       1.0
# 2015-01-08  3559.26 -0.023472      -1.0
# 2015-01-09  3546.72 -0.003529      -1.0

# %%
data['strategy'] = data['position'].shift(1) * data['returns']

# %%
data.head(10)
# Out:
#               price   returns  position  strategy
# date
# 2015-01-05  3641.54       NaN       NaN       NaN
# 2015-01-06  3641.06 -0.000132      -1.0       NaN
# 2015-01-07  3643.79  0.000750       1.0 -0.000750
# 2015-01-08  3559.26 -0.023472      -1.0 -0.023472
# 2015-01-09  3546.72 -0.003529      -1.0  0.003529
# 2015-01-12  3513.58 -0.009388      -1.0  0.009388
# 2015-01-13  3514.04  0.000131       1.0 -0.000131
# 2015-01-14  3502.42 -0.003312      -1.0 -0.003312
# 2015-01-15  3604.12  0.028623       1.0 -0.028623
# 2015-01-16  3635.15  0.008573       1.0  0.008573

# %%
data[['returns','strategy']].cumsum().apply(np.exp).plot(figsize=(10, 6))

# %%
data['position_5'] = np.sign(data['returns'].rolling(5).mean())

# %%
data.head()
# Out:
#               price   returns  position  strategy  position_5
# date
# 2015-01-05  3641.54       NaN       NaN       NaN         NaN
# 2015-01-06  3641.06 -0.000132      -1.0       NaN         NaN
# 2015-01-07  3643.79  0.000750       1.0 -0.000750         NaN
# 2015-01-08  3559.26 -0.023472      -1.0 -0.023472         NaN
# 2015-01-09  3546.72 -0.003529      -1.0  0.003529         NaN

# %%
data['strategy_5'] = data['position_5'].shift(1) * data['returns']

# %%
data[['returns','strategy_5']].dropna().cumsum().apply(np.exp).plot(figsize=(10,6))

# %% [markdown]
# #### 参数寻优——使用离散Return计算方法

# %%
data['returns_dis'] = data['price'] /data['price'].shift(1) -1
data['returns_dis_cum'] = (data['returns_dis'] + 1).cumprod()
data.head()
# Out:
#               price   returns  position  strategy  position_5  strategy_5  \
# date
# 2015-01-05  3641.54       NaN       NaN       NaN         NaN         NaN
# 2015-01-06  3641.06 -0.000132      -1.0       NaN         NaN         NaN
# 2015-01-07  3643.79  0.000750       1.0 -0.000750         NaN         NaN
# 2015-01-08  3559.26 -0.023472      -1.0 -0.023472         NaN         NaN
# 2015-01-09  3546.72 -0.003529      -1.0  0.003529         NaN         NaN
#
#             returns_dis  returns_dis_cum
# date
# 2015-01-05          NaN              NaN
# 2015-01-06    -0.000132         0.999868
# 2015-01-07     0.000750         1.000618
# 2015-01-08    -0.023198         0.977405
# 2015-01-09    -0.003523         0.973962

# %%
price_plot = ['returns_dis_cum']
type(price_plot)
# Out:
# list

# %%
for days in [10,20,30,60]:
    price_plot.append('sty_cumr_%dd' % days)
    data['position_%dd' % days] = np.where(data['returns'].rolling(days).mean() > 0, 1, -1)
    data['strategy_%dd' % days] = data['position_%dd' % days].shift(1) * data['returns']
    data['sty_cumr_%dd' % days] = (data['strategy_%dd' % days]+1).cumprod()

# %%
data.head()
# Out:
#               price   returns  position  strategy  position_5  strategy_5  \
# date
# 2015-01-05  3641.54       NaN       NaN       NaN         NaN         NaN
# 2015-01-06  3641.06 -0.000132      -1.0       NaN         NaN         NaN
# 2015-01-07  3643.79  0.000750       1.0 -0.000750         NaN         NaN
# 2015-01-08  3559.26 -0.023472      -1.0 -0.023472         NaN         NaN
# 2015-01-09  3546.72 -0.003529      -1.0  0.003529         NaN         NaN
#
#             returns_dis  returns_dis_cum  position_10d  strategy_10d  \
# date
# 2015-01-05          NaN              NaN            -1           NaN
# 2015-01-06    -0.000132         0.999868            -1      0.000132
# 2015-01-07     0.000750         1.000618            -1     -0.000750
# 2015-01-08    -0.023198         0.977405            -1      0.023472
# 2015-01-09    -0.003523         0.973962            -1      0.003529
#
#             sty_cumr_10d  position_20d  strategy_20d  sty_cumr_20d  \
# date
# 2015-01-05           NaN            -1           NaN           NaN
# 2015-01-06      1.000132            -1      0.000132      1.000132
# 2015-01-07      0.999382            -1     -0.000750      0.999382
# 2015-01-08      1.022839            -1      0.023472      1.022839
# 2015-01-09      1.026449            -1      0.003529      1.026449
#
#             position_30d  strategy_30d  sty_cumr_30d  position_60d  \
# date
# 2015-01-05            -1           NaN           NaN            -1
# 2015-01-06            -1      0.000132      1.000132            -1
# 2015-01-07            -1     -0.000750      0.999382            -1
# 2015-01-08            -1      0.023472      1.022839            -1
# 2015-01-09            -1      0.003529      1.026449            -1
#
#             strategy_60d  sty_cumr_60d
# date
# 2015-01-05           NaN           NaN
# 2015-01-06      0.000132      1.000132
# 2015-01-07     -0.000750      0.999382
# 2015-01-08      0.023472      1.022839
# 2015-01-09      0.003529      1.026449

# %%
price_plot
# Out:
# ['returns_dis_cum',
#  'sty_cumr_10d',
#  'sty_cumr_20d',
#  'sty_cumr_30d',
#  'sty_cumr_60d']

# %%
data[price_plot].dropna().plot(
    title='HS300 Multi Parameters Momuntum Strategy',
    figsize=(10,6), style=['--','--','--','--','--'])

# %%
hs300_hf = ts.get_k_data('hs300', ktype='5')
hs300_hf.head(10)
# Out:
#                date     open    close     high      low     volume amount  \
# 0  2019-12-06 14:55  3896.24  3898.51  3898.78  3895.64  2932527.0     {}
# 1  2019-12-06 15:00  3898.51  3902.39  3902.39  3898.51  2145069.0     {}
# 2  2019-12-09 09:35  3909.53  3908.06  3911.97  3906.09  7259085.0     {}
# 3  2019-12-09 09:40  3908.06  3893.76  3908.08  3893.19  4331776.0     {}
# 4  2019-12-09 09:45  3893.76  3899.77  3899.77  3893.76  3592399.0     {}
# 5  2019-12-09 09:50  3899.77  3896.52  3900.19  3896.43  3476185.0     {}
# 6  2019-12-09 09:55  3896.52  3894.45  3896.88  3893.05  3398196.0     {}
# 7  2019-12-09 10:00  3894.45  3894.44  3895.02  3893.00  2625516.0     {}
# 8  2019-12-09 10:05  3894.44  3895.46  3896.96  3894.26  3121485.0     {}
# 9  2019-12-09 10:10  3895.46  3890.13  3895.61  3890.00  2543472.0     {}
#
#   turnoverratio   code
# 0        0.0000  hs300
# 1        0.0000  hs300
# 2        0.0000  hs300
# 3        0.0000  hs300
# 4        0.0000  hs300
# 5        0.0000  hs300
# 6        0.0000  hs300
# 7        0.0000  hs300
# 8        0.0000  hs300
# 9        0.0000  hs300

# %%
hs300_hf.head()
# Out:
#                      open    close     high      low     volume amount  \
# date
# 2019-12-06 14:55  3896.24  3898.51  3898.78  3895.64  2932527.0     {}
# 2019-12-06 15:00  3898.51  3902.39  3902.39  3898.51  2145069.0     {}
# 2019-12-09 09:35  3909.53  3908.06  3911.97  3906.09  7259085.0     {}
# 2019-12-09 09:40  3908.06  3893.76  3908.08  3893.19  4331776.0     {}
# 2019-12-09 09:45  3893.76  3899.77  3899.77  3893.76  3592399.0     {}
#
#                  turnoverratio   code
# date
# 2019-12-06 14:55        0.0000  hs300
# 2019-12-06 15:00        0.0000  hs300
# 2019-12-09 09:35        0.0000  hs300
# 2019-12-09 09:40        0.0000  hs300
# 2019-12-09 09:45        0.0000  hs300

# %%
hs300_hf['2019-12-09':'2019-12-15'].head()
# Out:
#                      open    close     high      low     volume amount  \
# date
# 2019-12-09 09:35  3909.53  3908.06  3911.97  3906.09  7259085.0     {}
# 2019-12-09 09:40  3908.06  3893.76  3908.08  3893.19  4331776.0     {}
# 2019-12-09 09:45  3893.76  3899.77  3899.77  3893.76  3592399.0     {}
# 2019-12-09 09:50  3899.77  3896.52  3900.19  3896.43  3476185.0     {}
# 2019-12-09 09:55  3896.52  3894.45  3896.88  3893.05  3398196.0     {}
#
#                  turnoverratio   code
# date
# 2019-12-09 09:35        0.0000  hs300
# 2019-12-09 09:40        0.0000  hs300
# 2019-12-09 09:45        0.0000  hs300
# 2019-12-09 09:50        0.0000  hs300
# 2019-12-09 09:55        0.0000  hs300

# %%
hs300_hf['returns'] = np.log(hs300_hf['close'] / hs300_hf['close'].shift(1))

# %%
hs300_hf['position'] = np.sign(hs300_hf['returns'].rolling(10).mean())

# %%
hs300_hf['strategy'] = hs300_hf['position'].shift(1) * hs300_hf['returns']

# %%
hs300_hf[['returns','strategy']].dropna().cumsum().apply(np.exp).plot(figsize=(10,6),style=['--','--'])
