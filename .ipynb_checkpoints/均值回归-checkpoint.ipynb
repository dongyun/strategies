# %% [markdown]
# # 均值回归策略

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
import matplotlib as mpl
mpl.rcParams['font.family'] = 'serif'
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import tushare as ts

# %% [markdown]
# ### 策略思想
# 均值回归策略应用了股市投资中经典的高抛低吸思想，该类型策略一般在政党市中表现优秀；但是在
# 单边趋势行情中一般表现糟糕，往往会大幅跑输市场；

# %% [markdown]
# ### 前导知识

# %%
a = pd.DataFrame([np.NaN,1,1,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,0,0,0])
a
# Out:
#       0
# 0   NaN
# 1   1.0
# 2   1.0
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   0.0
# 10  0.0
# 11  0.0

# %%
a.ffill().fillna(0)
# Out:
#       0
# 0   0.0
# 1   1.0
# 2   1.0
# 3   1.0
# 4   1.0
# 5   1.0
# 6   1.0
# 7   1.0
# 8   1.0
# 9   0.0
# 10  0.0
# 11  0.0

# %% [markdown]
# ### 数据准备 & 回测准备

# %%
data = ts.get_k_data('hs300', start='2015-01-01', end='2019-12-20')[['date','close']]

# %%
data.rename(columns={'close':'price'},inplace=True)

# %%
data['price'].plot(figsize = (10,8))

# %%
data.head()
# Out:
#               price
# date
# 2015-01-05  3641.54
# 2015-01-06  3641.06
# 2015-01-07  3643.79
# 2015-01-08  3559.26
# 2015-01-09  3546.72

# %% [markdown]
#  ### 策略开发思路

# %%
data['returns'] = np.log(data['price'] / data['price'].shift(1))

# %%
SMA = 50
data['SMA'] = data['price'].rolling(SMA).mean()

# %%
data.tail()
# Out:
#               price   returns        SMA
# date
# 2019-12-16  3987.55  0.004859  3903.5954
# 2019-12-17  4041.80  0.013513  3907.6778
# 2019-12-18  4032.78 -0.002234  3911.4686
# 2019-12-19  4027.15 -0.001397  3914.5188
# 2019-12-20  4017.25 -0.002461  3916.6292

# %%
threshold = 250 #阙值；

# %%
data['distance'] = data['price'] - data['SMA']

# %%
data['distance'].dropna().plot(figsize = (10,6), legend=True)
plt.axhline(threshold, color='r')
plt.axhline(-threshold, color='r')
plt.axhline(0, color='r')

# %%
data['position'] = np.where(data['distance'] > threshold, -1, np.nan)

# %%
data['position'] = np.where(data['distance'] < -threshold, 1 , data['position'])

# %%
data['position'] = np.where(data['distance'] * data['distance'].shift(1) < 0, 0, data['position'])

# %%
data['position'] = data['position'].ffill().fillna(0)

# %%
data['position'].ix[SMA:].plot(ylim=[-1.1, 1.1], figsize=(10,6))

# %% [markdown]
# ### 3,计算策略年化收益并可视化

# %%
data['strategy'] = data['position'].shift(1) * data['returns']

# %%
data[['returns','strategy']].dropna().cumsum().apply(np.exp).plot(figsize= (10,6))
